# %%
try:
    from google.colab import userdata
    groq_key = userdata.get('Groq_Key')
    if groq_key:
        print("Groq API key loaded successfully")
    else:
        print("Warning: Groq API key not found")
except ImportError:
    print("Error: google.colab not available")
except Exception as e:
    print(f"Error loading Groq key: {e}")
# Out:
# Groq API key loaded successfully

# %%
try:
    from google.colab import userdata
    gemini_key = userdata.get('Gemini_key')
    if gemini_key:
        print("Gemini API key loaded successfully")
    else:
        print("Warning: Gemini API key not found")
except ImportError:
    print("Error: google.colab not available")
except Exception as e:
    print(f"Error loading Gemini key: {e}")
# Out:
# Gemini API key loaded successfully

# %%
try:
    # !pip install groq -q
    print("Groq package installed successfully")
except Exception as e:
    print(f"Error installing groq: {e}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.8 MB/s eta 0:00:00
# Groq package installed successfully

# %%
try:
    from groq import Groq
    from google.colab import userdata

    api_key = userdata.get('Groq_Key')
    if not api_key:
        raise ValueError("Groq API key not found")

    client = Groq(api_key=api_key)

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "user", "content": "Hello, who are you?"}
        ]
    )

    print(response.choices[0].message.content)

except ImportError:
    print("Error: groq package not installed")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error during API call: {e}")
# Out:
# Hello. I'm an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."

# %% [markdown]
# Install RAG Packages

# %%
try:
    # !pip install langchain langchain-community pypdf chromadb -q
    print("RAG packages installed successfully")
except Exception as e:
    print(f"Error installing RAG packages: {e}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 68.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 81.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 74.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
try:
    import langchain
    import chromadb
    import pypdf
    print("All packages imported successfully!")
except ImportError as e:
    print(f"Import Error: {e}")
except Exception as e:
    print(f"Unexpected error during import: {e}")
# Out:
# All packages imported successfully!

# %%
try:
    # !pip install groq -q

    from groq import Groq
    from google.colab import userdata

    api_key = userdata.get("Groq_Key")
    if not api_key:
        raise ValueError("Groq API key not found")

    client = Groq(api_key=api_key)

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {
                "role": "user",
                "content": "What is RAG in AI?"
            }
        ]
    )

    print(response.choices[0].message.content)

except ImportError:
    print("Error: Required packages not installed")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error during RAG explanation request: {e}")
# Out:
# RAG (Retrieval-Augmented Generation) is a relatively new paradigm in artificial intelligence (AI), specifically in the field of natural language processing (NLP). It involves combining two main components:
#
# 1. **Retrieval**: This component is responsible for retrieving relevant information from a large database or knowledge base. The retrieval system searches for and fetches relevant documents, passages, or texts that are related to the input prompt or question.
# 2. **Generation**: This component is a traditional language generation model that takes the retrieved information as input and generates a response or answer to the input prompt.
#
# The key idea behind RAG is to augment the generation process with retrieval, allowing the model to draw upon a large external knowledge base and generate more accurate, informative, and context-dependent responses. This approach has shown significant improvements in various NLP tasks, including:
#
# * Question answering
# ...

# %% [markdown]
# # Notebook Documentation
#
# ## Overview
# This notebook demonstrates Groq API integration with Llama models, including basic API testing, RAG setup, and LLM queries with proper error handling.
#
# ## Dependencies
# - groq
# - langchain
# - langchain-community
# - chromadb
# - pypdf
#
# ## Setup Requirements
#
# ### API Key Configuration
# Before running this notebook, set up your Groq API key:
#
# 1. **Google Colab Users:**
#    - Click on 🔑 Secrets icon in left sidebar
#    - Add a new secret named `Groq_Key`
#    - Paste your Groq API key as the value
#
# 2. **Local Environment Users:**
#    - Set environment variable: `export GROQ_API_KEY="your_api_key_here"`
#    - Or use `.env` file with python-dotenv
#
# ### Getting a Groq API Key
# 1. Visit [Groq Console](https://console.groq.com)
# 2. Sign up/Login with your email
# 3. Navigate to API Keys section
# 4. Click "Create API Key"
# 5. Copy and save the generated key
#
# ### Optional: Gemini API Key
# - **Secret Name**: `Gemini_key`
# - **Get from**: [Google AI Studio](https://makersuite.google.com/app/apikey)
#
# ## Code Structure
#
# ### Cell 1: Load Groq API Key
# Retrieves Groq API key from Colab secrets with validation.
#
# ### Cell 2: Load Gemini API Key
# Optional loading of Gemini API key.
#
# ### Cell 3: Install Groq Package
# Installs the Groq Python package.
#
# ### Cell 4: Basic Groq API Test
# - Initializes Groq client
# - Sends "Hello, who are you?" query
# - Displays Llama 3.3 model response
#
# ### Cell 5: Install RAG Dependencies
# Installs LangChain, ChromaDB, and PyPDF for RAG.
#
# ### Cell 6: Import RAG Libraries
# Imports LangChain ecosystem packages.
#
# ### Cell 7: RAG Explanation Query
# Queries Llama model for comprehensive RAG explanation.
