# %%
from google.colab import userdata

key = userdata.get("Groq_Key")

if key:
    print("✅ GROQ_KEY loaded successfully")
else:
    print("❌ GROQ_KEY not found")
# Out:
# ✅ GROQ_KEY loaded successfully

# %%
print("key loaded successfully")

# %%
from google.colab import userdata
key = userdata.get('Gemini_key')

if key:
    print("✅ Gemini_KEY loaded successfully")
else:
    print("❌ Gemini_KEY not found")
# Out:
# ✅ Gemini_KEY loaded successfully

# %%
# !pip install groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.1 MB/s eta 0:00:00

# %%
print("Hello RAG")
# Out:
# Hello RAG

# %% [markdown]
# from groq import Groq
#
# client = Groq(api_key="Groq_Key")
#
# response = client.chat.completions.create(
#     model="llama-3.3-70b-versatile",
#     messages=[
#         {"role": "user", "content": "Hello, who are you?"}
#     ]
# )
#
# print(response.choices[0].message.content)

# %%
# !pip install langchain langchain-community pypdf chromadb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.9/343.9 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 121.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 93.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.

# %%
import langchain
import chromadb
import pypdf

print("All packages imported successfully!")
# Out:
# All packages imported successfully!

# %%
# !pip install groq -q

from groq import Groq
from google.colab import userdata

client = Groq(
    api_key=userdata.get("Groq_Key")
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "What is RAG in AI?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# RAG (Retrieval-Augmented Generation) is a technique used in artificial intelligence (AI), specifically in natural language processing (NLP) and language models. It combines the strengths of retrieval-based and generation-based approaches to produce more accurate and informative responses.
#
# In RAG, the model consists of two main components:
#
# 1. **Retriever**: This component is responsible for retrieving relevant information from a large database or knowledge base. The retriever uses a query (e.g., a question or prompt) to search for and retrieve the most relevant documents, passages, or snippets.
# 2. **Generator**: This component takes the retrieved information and uses it to generate a response. The generator can be a language model, such as a transformer, that uses the retrieved context to produce a coherent and accurate answer.
#
# The RAG framework has several benefits:
#
# * **Improved accuracy**: By leveraging the retriever to fetch relevant information, the generator can produce more accurate responses.
# * **Increased context understanding**: The retriever provides the generator with a broader context, enabling it to better comprehend the question or prompt.
# * **Reducing hallucination**: RAG helps to reduce hallucination (i.e., generating information that is not supported by the input or context) by grounding the generator's output in the retrieved information.
#
# RAG has been applied to various NLP tasks, including question answering, text summarization, and dialogue systems. It has shown promising results in these areas, particularly in scenarios where the model needs to provide accurate and informative responses based on a large volume of knowledge.
